# %% [markdown]
# <a href="https://colab.research.google.com/github/NIKHILNARSIPALLI/Electric-and-Alternate-Fuel/blob/main/EDA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Electric and Alternative Fuel Charging Stations.csv')
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (6,16,20,31,33,36,39,40,41,43,46,52,53,55,57,58,60,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   Fuel Type Code                                  Station Name  \
# 0            CNG          Spire - Montgomery Operations Center
# 1            CNG                           PS Energy - Atlanta
# 2            CNG  Metropolitan Atlanta Rapid Transit Authority
# 3            CNG                         United Parcel Service
# 4            CNG                    Arkansas Oklahoma Gas Corp
#
#          Street Address                            Intersection Directions  \
# 0      2951 Chestnut St                                                NaN
# 1      340 Whitehall St  From I-7585 N, exit 91 to Central Ave, left on...
# 2   2424 Piedmont Rd NE                                                NaN
# ...

# %%
df.shape
# Out:
# (70406, 65)

# %%
df.tail()
# Out:
#       Fuel Type Code               Station Name          Street Address  \
# 70401           ELEC  SCHLITZ PARK SCHLITZ PARK  1555 N River Center Dr
# 70402           ELEC       NEXUS EAST STATION 2        720 Airport Blvd
# 70403           ELEC                    Raley's   6119 Horseshoe Bar Rd
# 70404           ELEC        13601 Glenoaks blvd     13601 Glenoaks blvd
# 70405           ELEC         6723 Van Nuys blvd      6723 Van Nuys Blvd
#
#       Intersection Directions         City State    ZIP  Plus4 Station Phone  \
# 70401                     NaN    Milwaukee    WI  53212    NaN  888-758-4389
# 70402                     NaN       Austin    TX  78702    NaN  888-758-4389
# 70403                     NaN       Loomis    CA  95650    NaN  877-455-3833
# 70404                     NaN  Los Angeles    CA  91342    NaN  888-356-8911
# 70405                     NaN  Los Angeles    CA  91405    NaN  888-356-8911
#
#       Status Code  ... EV Pricing (French) LPG Nozzle Types  \
# ...

# %%
df.isnull()
# Out:
#        Fuel Type Code  Station Name  Street Address  Intersection Directions  \
# 0               False         False           False                     True
# 1               False         False           False                    False
# 2               False         False           False                     True
# 3               False         False           False                     True
# 4               False         False           False                     True
# ...               ...           ...             ...                      ...
# 70401           False         False           False                     True
# 70402           False         False           False                     True
# 70403           False         False           False                     True
# 70404           False         False           False                     True
# 70405           False         False           False                     True
#
# ...

# %%
df.describe()
# Out:
#        Plus4  EV Level1 EVSE Num  EV Level2 EVSE Num  EV DC Fast Count  \
# count    0.0          286.000000        54144.000000       8307.000000
# mean     NaN            3.461538            2.315289          3.576381
# std      NaN            6.548356            3.157387          4.129470
# min      NaN            1.000000            1.000000          1.000000
# 25%      NaN            1.000000            2.000000          1.000000
# 50%      NaN            1.000000            2.000000          2.000000
# 75%      NaN            2.000000            2.000000          4.000000
# max      NaN           51.000000          311.000000         56.000000
#
#            Latitude     Longitude             ID  Federal Agency ID  \
# count  70406.000000  70406.000000   70406.000000         955.000000
# mean      38.929309    -96.061447  148730.326066          13.905759
# std        5.628458     19.545273   54261.672118           6.767439
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70406 entries, 0 to 70405
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Fuel Type Code                    70406 non-null  object
#  1   Station Name                      70406 non-null  object
#  2   Street Address                    70405 non-null  object
#  3   Intersection Directions           4493 non-null   object
#  4   City                              70406 non-null  object
#  5   State                             70406 non-null  object
#  6   ZIP                               70405 non-null  object
#  7   Plus4                             0 non-null      float64
#  8   Station Phone                     65204 non-null  object
#  9   Status Code                       70406 non-null  object
#  10  Expected Date                     1218 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Fuel Type Code                     0
# Station Name                       0
# Street Address                     1
# Intersection Directions        65913
# City                               0
#                                ...
# CNG PSI                        68809
# CNG Vehicle Class              68784
# LNG Vehicle Class              70248
# EV On-Site Renewable Source    70036
# Restricted Access              16971
# Length: 65, dtype: int64

# %%
df.isnull().mean() * 100
#percentage of null values in each column
# Out:
# Fuel Type Code                  0.000000
# Station Name                    0.000000
# Street Address                  0.001420
# Intersection Directions        93.618442
# City                            0.000000
#                                  ...
# CNG PSI                        97.731727
# CNG Vehicle Class              97.696219
# LNG Vehicle Class              99.775587
# EV On-Site Renewable Source    99.474477
# Restricted Access              24.104480
# Length: 65, dtype: float64

# %%
null_percentage = df.isnull().mean()*100 >= 30

# %%
null_percentage.describe()
# Out:
# count       65
# unique       2
# top       True
# freq        40
# dtype: object

# %%
#removing the colums which have more than 30percent of missing values
df2 = df[[column for column in df if df[column].count() / len(df) >= 0.3]]
df2.shape
# Out:
# (70406, 27)

# %%
df.shape
# Out:
# (70406, 65)

# %%
df2.isnull().sum()
# Out:
# Fuel Type Code                          0
# Station Name                            0
# Street Address                          1
# City                                    0
# State                                   0
# ZIP                                     1
# Station Phone                        5202
# Status Code                             0
# Groups With Access Code                 0
# Access Days Time                     3778
# EV Level2 EVSE Num                  16262
# EV Network                           9499
# EV Network Web                      20101
# Geocode Status                         15
# Latitude                                0
# Longitude                               0
# Date Last Confirmed                   218
# ID                                      0
# Updated At                              0
# Owner Type Code                     40216
# Open Date                            1096
# EV Connector Types                   9716
# ...

# %%
for column in df:
  print(column,end=" ")
  print((df[column].count()/len(df)).round(4)*100)
# Out:
# Fuel Type Code 100.0
# Station Name 100.0
# Street Address 100.0
# Intersection Directions 6.38
# City 100.0
# State 100.0
# ZIP 100.0
# Plus4 0.0
# Station Phone 92.61
# Status Code 100.0
# Expected Date 1.73
# Groups With Access Code 100.0
# Access Days Time 94.63000000000001
# Cards Accepted 16.03
# BD Blends 1.73
# NG Fill Type Code 2.2800000000000002
# NG PSI 2.27
# EV Level1 EVSE Num 0.41000000000000003
# EV Level2 EVSE Num 76.9
# EV DC Fast Count 11.799999999999999
# EV Other Info 0.06999999999999999
# EV Network 86.50999999999999
# EV Network Web 71.45
# Geocode Status 99.98
# Latitude 100.0
# Longitude 100.0
# Date Last Confirmed 99.69
# ID 100.0
# Updated At 100.0
# Owner Type Code 42.88
# Federal Agency ID 1.3599999999999999
# Federal Agency Name 1.3599999999999999
# Open Date 98.44000000000001
# Hydrogen Status Link 0.12
# NG Vehicle Class 2.53
# LPG Primary 2.65
# E85 Blender Pump 6.4
# EV Connector Types 86.2
# Country 100.0
# Intersection Directions (French) 0.27
# ...

# %%
df['Fuel Type Code'].unique()
# Out:
# array(['CNG', 'E85', 'ELEC', 'LNG', 'LPG', 'BD', 'HY'], dtype=object)

# %%
df['EV Network'].unique()
# Out:
# array([nan, 'Non-Networked', 'Volta', 'EV Connect', 'POWERFLEX',
#        'ChargePoint Network', 'OpConnect', 'SemaCharge Network',
#        'Tesla Destination', 'Greenlots', 'EVGATEWAY', 'eVgo Network',
#        'Webasto', 'CHARGELAB', 'AMPUP', 'PETROCAN', 'FLO',
#        'Sun Country Highway', 'AddÉnergie Technologies', 'Tesla',
#        'BCHYDRO', 'SWTCH', 'EVCS', 'Blink Network', 'FCN',
#        'Electrify America', 'Circuit électrique', 'eCharge Network',
#        'IVY', 'Electrify Canada', 'FPLEV', 'ZEFNET', 'LIVINGSTON',
#        'RIVIAN_WAYPOINTS', 'RIVIAN_ADVENTURE'], dtype=object)

# %%
df['Access Days Time'].unique()
# Out:
# array([nan, '24 hours daily',
#        '24 hours daily; call 866-809-4869 for Clean Energy card', ...,
#        '7:30am-7pm M-F; 8am-6pm Sat; Closed Sunday',
#        '24 hours daily; Phone App',
#        'Mon 7:00am - 6:00pm; Tue 7:00am - 6:00pm; Wed 7:00am - 6:00pm; Thu 7:00am - 6:00pm; Fri 7:00am - 6:00pm'],
#       dtype=object)

# %%
df['State'].unique()
# Out:
# array(['AL', 'GA', 'AR', 'MA', 'NY', 'IN', 'WY', 'CT', 'LA', 'NM', 'KS',
#        'ID', 'MO', 'TX', 'UT', 'MN', 'NE', 'CO', 'OR', 'OK', 'PA', 'CA',
#        'FL', 'SC', 'NC', 'AZ', 'NV', 'VA', 'MD', 'WA', 'TN', 'SD', 'IA',
#        'IL', 'MI', 'ND', 'NJ', 'MS', 'OH', 'MT', 'RI', 'NH', 'WV', 'WI',
#        'HI', 'VT', 'AK', 'ME', 'KY', 'DC', 'DE', 'AB', 'QC', 'MB', 'SK',
#        'ON', 'BC', 'NL', 'PE', 'NB', 'NS', 'NT', 'YT', 'PR', 'MX'],
#       dtype=object)

# %%
df['State'].nunique(dropna=True)
# Out:
# 65
